# %% [markdown]
# <a href="https://colab.research.google.com/github/Katherin234/Inteligencia-artificial/blob/main/LeccionPandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
url = '/content/cta_Ridership_exported.csv'
df = pd.read_csv(url)
print(df.head())
# Out:
#    station_id       stationname        date daytype  rides
# 0       41280    Jefferson Park  12/22/2017       W   6104
# 1       41000  Cermak-Chinatown  12/18/2017       W   3636
# 2       40280      Central-Lake  12/02/2017       A   1270
# 3       40140   Dempster-Skokie  12/19/2017       W   1759
# 4       40690          Dempster  12/03/2017       U    499

# %%
df.tail()
# Out:
#          station_id        stationname        date daytype  rides
# 1145581       41700  Washington/Wabash  12/27/2022       W   3991
# 1145582       41700  Washington/Wabash  12/28/2022       W   4100
# 1145583       41700  Washington/Wabash  12/29/2022       W   4741
# 1145584       41700  Washington/Wabash  12/30/2022       W   4664
# 1145585       41700  Washington/Wabash  12/31/2022       A   2774

# %%
df.shape
# Out:
# (1145586, 5)

# %%
df.dtypes
# Out:
# station_id      int64
# stationname    object
# date           object
# daytype        object
# rides           int64
# dtype: object

# %%
df.describe()
# Out:
#          station_id         rides
# count  1.145586e+06  1.145586e+06
# mean   4.076649e+04  3.056635e+03
# std    4.490665e+02  3.118576e+03
# min    4.001000e+04  0.000000e+00
# 25%    4.037000e+04  9.630000e+02
# 50%    4.076000e+04  2.004000e+03
# 75%    4.115000e+04  4.025000e+03
# max    4.170000e+04  3.632300e+04

# %%
df.iloc[[100, 200, 300]]
# Out:
#      station_id        stationname        date daytype  rides
# 100       41410  Chicago/Milwaukee  12/07/2017       W   4495
# 200       40060     Belmont-O'Hare  12/02/2017       A   3327
# 300       41240     Addison-O'Hare  12/04/2017       W   3034

# %%
# Leer el archivo CSV en un DataFrame
df = pd.read_csv(url)

# %%
# Convertir la columna 'date' al formato datetime
df['date'] = pd.to_datetime(df['date'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3652         try:
# -> 3653             return self._engine.get_loc(casted_key)
#    3654         except KeyError as err:
#
# /usr/local/lib/python3.10/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# /usr/local/lib/python3.10/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'date'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ...

# %%
#Primero echemos un vistazo rápido a cómo se ven estos datos
df.head()
# Out:
#    station_id       stationname        date daytype  rides
# 0       41280    Jefferson Park  12/22/2017       W   6104
# 1       41000  Cermak-Chinatown  12/18/2017       W   3636
# 2       40280      Central-Lake  12/02/2017       A   1270
# 3       40140   Dempster-Skokie  12/19/2017       W   1759
# 4       40690          Dempster  12/03/2017       U    499

# %%
print(df.shape)
print(df.head())
print(df.tail())
print(df.dtypes)
print(type(df))
# Out:
# (1145586, 5)
#    station_id       stationname        date daytype  rides
# 0       41280    Jefferson Park  12/22/2017       W   6104
# 1       41000  Cermak-Chinatown  12/18/2017       W   3636
# 2       40280      Central-Lake  12/02/2017       A   1270
# 3       40140   Dempster-Skokie  12/19/2017       W   1759
# 4       40690          Dempster  12/03/2017       U    499
#          station_id        stationname        date daytype  rides
# 1145581       41700  Washington/Wabash  12/27/2022       W   3991
# 1145582       41700  Washington/Wabash  12/28/2022       W   4100
# 1145583       41700  Washington/Wabash  12/29/2022       W   4741
# 1145584       41700  Washington/Wabash  12/30/2022       W   4664
# 1145585       41700  Washington/Wabash  12/31/2022       A   2774
# station_id      int64
# stationname    object
# date           object
# daytype        object
# rides           int64
# dtype: object
# <class 'pandas.core.frame.DataFrame'>

# %%
# usar el módulo de descripción
df.describe()
# Out:
#          station_id         rides
# count  1.145586e+06  1.145586e+06
# mean   4.076649e+04  3.056635e+03
# std    4.490665e+02  3.118576e+03
# min    4.001000e+04  0.000000e+00
# 25%    4.037000e+04  9.630000e+02
# 50%    4.076000e+04  2.004000e+03
# 75%    4.115000e+04  4.025000e+03
# max    4.170000e+04  3.632300e+04

# %%
#definir el valor minimo de rides
df['rides'].min()
# Out:
# 0

# %%
#definir el valor maximo de rides
df['rides'].max()
# Out:
# 36323

# %%
minimo = df['rides'].min()
maximo = df['rides'].max()
print(minimo)
print(maximo)
# Out:
# 0
# 36323

# %%
print(df.columns)
# Out:
# Index(['station_id', 'stationname', 'date', 'daytype', 'rides'], dtype='object')

# %%
import pandas as pd
url = 'https://raw.githubusercontent.com/Sinchiguano/chicagoUniversity/main/cta_Ridership.csv'
df = pd.read_csv(url)
df.set_index('date', inplace=True)
print(df.head())
# Out:
#             station_id       stationname daytype  rides
# date
# 12/22/2017       41280    Jefferson Park       W   6104
# 12/18/2017       41000  Cermak-Chinatown       W   3636
# 12/02/2017       40280      Central-Lake       A   1270
# 12/19/2017       40140   Dempster-Skokie       W   1759
# 12/03/2017       40690          Dempster       U    499

# %%
df.sort_values('rides', ascending=False)
# Out:
#             station_id         stationname daytype  rides
# date
# 06/28/2015       41320  Belmont-North Main       U  36323
# 06/24/2012       41320  Belmont-North Main       U  36017
# 11/04/2016       41660          Lake/State       W  35845
# 06/26/2011       41320  Belmont-North Main       U  33795
# 10/29/2016       41420  Addison-North Main       A  33615
# ...                ...                 ...     ...    ...
# 06/05/2008       41210          Wellington       W      0
# 09/03/2008       40090         Damen-Brown       W      0
# 01/29/2008       40530            Diversey       W      0
# 09/21/2003       40150      Pulaski-Cermak       U      0
# 06/27/2021       40770            Lawrence       U      0
#
# [1145586 rows x 4 columns]

# %%
Garfield_dan_Ryan = df[df['stationname'] == 'Garfield-Dan Ryan']
print(Garfield_dan_Ryan)
# Out:
#             station_id        stationname daytype  rides
# date
# 12/22/2017       41170  Garfield-Dan Ryan       W   3040
# 12/05/2017       41170  Garfield-Dan Ryan       W   3217
# 12/27/2017       41170  Garfield-Dan Ryan       W   2016
# 12/02/2017       41170  Garfield-Dan Ryan       A   2624
# 12/19/2017       41170  Garfield-Dan Ryan       W   2958
# ...                ...                ...     ...    ...
# 12/27/2022       41170  Garfield-Dan Ryan       W    976
# 12/28/2022       41170  Garfield-Dan Ryan       W    961
# 12/29/2022       41170  Garfield-Dan Ryan       W    991
# 12/30/2022       41170  Garfield-Dan Ryan       W   1135
# 12/31/2022       41170  Garfield-Dan Ryan       A    776
#
# [8005 rows x 4 columns]

# %%
Garfield_South_Elevated = df[df['stationname'] == 'Garfield-South Elevated']
print(Garfield_South_Elevated)
# Out:
#             station_id              stationname daytype  rides
# date
# 12/22/2017       40510  Garfield-South Elevated       W   1042
# 12/24/2017       40510  Garfield-South Elevated       U    431
# 12/09/2017       40510  Garfield-South Elevated       A    688
# 12/17/2017       40510  Garfield-South Elevated       U    486
# 12/31/2017       40510  Garfield-South Elevated       U    393
# ...                ...                      ...     ...    ...
# 12/27/2022       40510  Garfield-South Elevated       W    384
# 12/28/2022       40510  Garfield-South Elevated       W    436
# 12/29/2022       40510  Garfield-South Elevated       W    448
# 12/30/2022       40510  Garfield-South Elevated       W    472
# 12/31/2022       40510  Garfield-South Elevated       A    249
#
# [8035 rows x 4 columns]

# %%
import matplotlib.pyplot as plt
import seaborn as sns
sns.set(rc={'figure.figsize':(11, 4)})
Garfield_dan_Ryan['rides'].plot(linewidth=0.5)
plt.show()

# %%
sns.set(rc={'figure.figsize':(11, 4)})
Garfield_South_Elevated['rides'].plot(linewidth=0.5)
# Out:
# <Axes: xlabel='date'>
