# %% [markdown]
# <a href="https://colab.research.google.com/github/Katherin234/Inteligencia-artificial/blob/main/IA16_18Juliio.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd


print(pd.__version__)

serieData= pd.Series(data=[100, 200, 300], index=['juan','pedro','lucas'])

print(serieData)
print('/////')
print(serieData['pedro'])

print(serieData.index)
print('pedro' in serieData)

myDictionary={'one':pd.Series([100,200,300], index=['juan','pedro','lucas']),
                                  'two':pd.Series ([11,22,33], index=['julio', 'pedro', 'lucas']) }

#SERIES AND DATAFRAME
#
df=pd.DataFrame(myDictionary)
print(df)
print('we are here.....')
print(df.index)
print(df.columns)

print('////////////')
print(df.loc['juan'])
# Out:
# 2.0.3
# juan     100
# pedro    200
# lucas    300
# dtype: int64
# /////
# 200
# Index(['juan', 'pedro', 'lucas'], dtype='object')
# True
#          one   two
# juan   100.0   NaN
# julio    NaN  11.0
# lucas  300.0  33.0
# pedro  200.0  22.0
# we are here.....
# Index(['juan', 'julio', 'lucas', 'pedro'], dtype='object')
# Index(['one', 'two'], dtype='object')
# ////////////
# one    100.0
# two      NaN
# Name: juan, dtype: float64

# %%
#Clase de jueves 18 de julio
import pandas as pd
df=pd.read_csv('/content/movies.csv')

# %%
df
# Out:
#        movieId                               title  \
# 0            1                    Toy Story (1995)
# 1            2                      Jumanji (1995)
# 2            3             Grumpier Old Men (1995)
# 3            4            Waiting to Exhale (1995)
# 4            5  Father of the Bride Part II (1995)
# ...        ...                                 ...
# 62418   209157                           We (2018)
# 62419   209159           Window of the Soul (2001)
# 62420   209163                    Bad Poems (2018)
# 62421   209169                 A Girl Thing (2001)
# 62422   209171      Women of Devil's Island (1962)
#
#                                             genres
# 0      Adventure|Animation|Children|Comedy|Fantasy
# 1                       Adventure|Children|Fantasy
# 2                                   Comedy|Romance
# 3                             Comedy|Drama|Romance
# 4                                           Comedy
# ...

# %%
df.head(3)
# Out:
#    movieId                    title  \
# 0        1         Toy Story (1995)
# 1        2           Jumanji (1995)
# 2        3  Grumpier Old Men (1995)
#
#                                         genres
# 0  Adventure|Animation|Children|Comedy|Fantasy
# 1                   Adventure|Children|Fantasy
# 2                               Comedy|Romance

# %%
df.tail(3)
# Out:
#        movieId                           title                  genres
# 62420   209163                Bad Poems (2018)            Comedy|Drama
# 62421   209169             A Girl Thing (2001)      (no genres listed)
# 62422   209171  Women of Devil's Island (1962)  Action|Adventure|Drama

# %%
#Eliminacion de columnas
del df['genres']

# %%
df
# Out:
#        movieId                               title
# 0            1                    Toy Story (1995)
# 1            2                      Jumanji (1995)
# 2            3             Grumpier Old Men (1995)
# 3            4            Waiting to Exhale (1995)
# 4            5  Father of the Bride Part II (1995)
# ...        ...                                 ...
# 62418   209157                           We (2018)
# 62419   209159           Window of the Soul (2001)
# 62420   209163                    Bad Poems (2018)
# 62421   209169                 A Girl Thing (2001)
# 62422   209171      Women of Devil's Island (1962)
#
# [62423 rows x 2 columns]

# %%
df.shape
# Out:
# (62423, 2)

# %%
#imprimir columnas
df.columns
# Out:
# Index(['movieId', 'title'], dtype='object')

# %%
#Imprime el rango de datos
df.index
# Out:
# RangeIndex(start=0, stop=62423, step=1)

# %%
tmp=df.iloc[2234] #muestra

# %%
tmp
# Out:
# movieId              2325
# title      Orgazmo (1997)
# Name: 2234, dtype: object

# %%
tmp['movieId']
# Out:
# 2325

# %%
'title' in df.columns
# Out:
# True

# %%
#imprmir 3 muestras
df.iloc[[30,87,97]]
# Out:
#     movieId                                 title
# 30       31                Dangerous Minds (1995)
# 87       88                    Black Sheep (1996)
# 97       99  Heidi Fleiss: Hollywood Madam (1995)

# %%
df.describe()
# Out:
#              movieId
# count   62423.000000
# mean   122220.387646
# std     63264.744844
# min         1.000000
# 25%     82146.500000
# 50%    138022.000000
# 75%    173222.000000
# max    209171.000000

# %%
print(df['movieId'].min())
print(df['movieId'].max())
promedio=df['movieId'].mean()
promedio
# Out:
# 1
# 209171
# 122220.38764557935

# %%
#ratings = pd.read_csv('/content/ratings.csv')
tags=pd.read_csv('/content/tags.csv')

# %%
tags.isnull().any()

# %%
ratings = pd.read_csv('/content/ratings.csv')
ratings.isnull().any()
# Out:
# userId       False
# movieId       True
# rating        True
# timestamp     True
# dtype: bool

# %%
print(tags.shape)
aux1=tags.shape[0]
tags=tags.dropna()
print(aux1)
aux2=ratings.shape[0]
print(tags.shape)
print(f'muestras eliminadas en variables tags', (aux1-aux2))
# Out:
# (1093360, 4)
# 1093360
# (1093344, 4)
# muestras eliminadas en variables tags -611474

# %%
print(ratings.columns)
print(ratings['rating'].max())
print(f'muestras antes del filtro {ratings.shape}')
print(ratings['rating'].min())
calificacion_alta=ratings['rating']<=4
# Out:
# Index(['userId', 'movieId', 'rating', 'timestamp'], dtype='object')
# 5.0
# muestras antes del filtro (1704834, 4)
# 0.5

# %%
ratings_despues=ratings[calificacion_alta]
print(ratings_despues.shape)
# Out:
# (1306023, 4)
